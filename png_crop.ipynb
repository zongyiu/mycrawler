# %%
from PIL import Image
from IPython.display import display

# %%
Image.MAX_IMAGE_PIXELS = 500000000

# %%
# 載入圖片
image_path = './001.png'
image = Image.open(image_path)

# %%
width, height = image.size

# %%
width
# Out:
# 2560

# %%
height
# Out:
# 169765

# %%
i = 1
offset = 1200 
a = 926 + (i-1)*offset
b = 926 + (i)*offset
crop_area = (850, a, 1710, b)
cropped_image = image.crop(crop_area)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=860x1200>

# %%
i = 2
offset = 1200 
a = 926 + (i-1)*offset
b = 926 + (i)*offset
crop_area = (850, a, 1710, b)
cropped_image = image.crop(crop_area)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=860x1200>
